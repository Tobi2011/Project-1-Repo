# %%
# Analyzing data from below
# https://github.com/fivethirtyeight/data/tree/master/college-majors

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#allAges = pd.read_csv("Raw_Data/all-ages.csv")
#gradStudents = pd.read_csv("Raw_Data/grad-students.csv")
#recentGrads = pd.read_csv("Raw_Data/recent-grads.csv")
#majorsList = pd.read_csv("Raw_Data/majors-list.csv")
df1_FL_Edu_Wages = pd.read_csv("Raw_Data/FloridaEduWages.csv")
df2_FL_Occu_Wages = pd.read_csv("Raw_Data/FloridaOccuWages.csv")

#df1_allAges = allAges
#df2_gradStudents = gradStudents
#df3_recentGrads = recentGrads
#df4_majorsList = majorsList

# %%
allAges.head()
# Out:
#    Major_code                                  Major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     Major_category   Total  Employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# ...

# %%
gradStudents.head()
# Out:
#    Major_code                                   Major  \
# 0        5601                   CONSTRUCTION SERVICES
# 1        6004       COMMERCIAL ART AND GRAPHIC DESIGN
# 2        6211                  HOSPITALITY MANAGEMENT
# 3        2201  COSMETOLOGY SERVICES AND CULINARY ARTS
# 4        2001              COMMUNICATION TECHNOLOGIES
#
#                         Major_category  Grad_total  Grad_sample_size  \
# 0  Industrial Arts & Consumer Services        9173               200
# 1                                 Arts       53864               882
# 2                             Business       24417               437
# 3  Industrial Arts & Consumer Services        5411                72
# 4              Computers & Mathematics        9109               171
#
#    Grad_employed  Grad_full_time_year_round  Grad_unemployed  \
# 0           7098                       6511              681
# 1          40492                      29553             2482
# ...

# %%
recentGrads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
df4_majorsList.head()
df4_majorsList[df4_majorsList['FOD1P'].str.contains('bbbb')]
#df4_majorsList.info()
# Out:
#      FOD1P                              Major Major_Category
# 145  bbbb   N/A (less than bachelor's degree)            NaN

# %%
print(list(df1_allAges))
df1_allAges.info()
# Out:
# ['Major_code', 'Major', 'Major_category', 'Total', 'Employed', 'Employed_full_time_year_round', 'Unemployed', 'Unemployment_rate', 'Median', 'P25th', 'P75th']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 11 columns):
# Major_code                       173 non-null int64
# Major                            173 non-null object
# Major_category                   173 non-null object
# Total                            173 non-null int64
# Employed                         173 non-null int64
# Employed_full_time_year_round    173 non-null int64
# Unemployed                       173 non-null int64
# Unemployment_rate                173 non-null float64
# Median                           173 non-null int64
# P25th                            173 non-null int64
# P75th                            173 non-null float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 14.9+ KB

# %%
print(list(df2_gradStudents))
# Out:
# ['Major_code', 'Major', 'Major_category', 'Grad_total', 'Grad_sample_size', 'Grad_employed', 'Grad_full_time_year_round', 'Grad_unemployed', 'Grad_unemployment_rate', 'Grad_median', 'Grad_P25', 'Grad_P75', 'Nongrad_total', 'Nongrad_employed', 'Nongrad_full_time_year_round', 'Nongrad_unemployed', 'Nongrad_unemployment_rate', 'Nongrad_median', 'Nongrad_P25', 'Nongrad_P75', 'Grad_share', 'Grad_premium']

# %%
print(list(df3_recentGrads))
df3_recentGrads.info()
df3_recentGrads[df3_recentGrads.isnull().any(axis=1)]
# Out:
# ['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women', 'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time', 'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate', 'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs', 'Low_wage_jobs']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# ...

# %%
print(list(df4_majorsList))
#df4_majorsList[df4_majorsList.isnull().any(axis=1)]
df4_majorsList.info()
# Out:
# ['FOD1P', 'Major', 'Major_Category']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 3 columns):
# FOD1P             174 non-null object
# Major             174 non-null object
# Major_Category    173 non-null object
# dtypes: object(3)
# memory usage: 4.2+ KB

# %%
df1_allAges = df1_allAges.sort_values("Median", ascending= False)

df1_allAges
# Out:
#      Major_code                                              Major  \
# 59         2419                              PETROLEUM ENGINEERING
# 154        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 57         2417          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 55         2415                          METALLURGICAL ENGINEERING
# 58         2418                                NUCLEAR ENGINEERING
# 56         2416                     MINING AND MINERAL ENGINEERING
# 97         4005                   MATHEMATICS AND COMPUTER SCIENCE
# 48         2408                             ELECTRICAL ENGINEERING
# 45         2405                               CHEMICAL ENGINEERING
# 51         2411             GEOLOGICAL AND GEOPHYSICAL ENGINEERING
# 41         2401                              AEROSPACE ENGINEERING
# 47         2407                               COMPUTER ENGINEERING
# 54         2414                             MECHANICAL ENGINEERING
# ...

# %%
#plt.scatter(df1_allAges["Unemployment_rate"].head(10) * 100, df1_allAges["P75th"].head(10), marker="o", color="gold", edgecolor="black",alpha=.8)
#plt.scatter(df1_allAges["Unemployment_rate"] * 100, df1_allAges["Median"], marker="o", color="pink", edgecolor="black",alpha=.8)
plt.scatter(df1_allAges["Unemployment_rate"] * 100, df1_allAges["P25th"], marker="o", color="c", edgecolor="black",alpha=.8)

#plt.legend(["75th %", "Average", "25th %"])
plt.title("Unemployment Rate based on Average Income")
plt.xlabel("Unemployment Rate (%)")
plt.ylabel("Average Income")
plt.grid()
plt.show()

# %%
# = np.arange(len())
#df1_allAges.sort_values(df1_allAges.groupby("Major_category")["Unemployment_rate"], ascending = False)
plt.figure(figsize=(10,4))
plt.bar(df1_allAges["Major_category"], (df1_allAges["Unemployment_rate"] * 100))
plt.ylabel("Unemployment Rate (%)")
plt.xticks(rotation=90)
plt.show()
